# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# **Nombres / Apellidos:**
#
# **Código:**
#
#
#
# ---

# %% [markdown]
# ### **CASO Disneylandia: Adquiriendo Conocimiento a partir de datos no estructurados**

# %% [markdown]
# ---

# %% [markdown]
# ### **DATASET**
#
# El conjunto de datos **DisneylandiaComentarios.csv** incluye 42.656 reseñas de **3 Sucursales de Disneylandia**: París, California y Hong Kong, en 6 variables, y publicadas por visitantes en la plataforma **Trip Advisor**.
#
# Las variables que conforman este dataset son:
#
# **Review_ID:** identificación única proporcionada a cada reseña
#
# **Rating:** Valoración que emite el visitante en la sucursal visitada
#
# **Year_Month:** Año mes al que corresponde la visita
#
# **Reviewer_Location:** País de procedencia del visitante
#
# **Review_Text:** comentario realizado por el visitante
#
# **Branch:** ubicación del parque (sucursal) de Disneylandia (París, California, Hong Kong)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**SE SOLICITA:**
#
# Realizar los siguientes pasos necesarios para este breve proyecto de analítica:
#
# **Paso #1:  Carga del Dataset**
#
# **Paso #2: Preprocesamiento de los datos**
#
# - Aplicar las técnicas necesarias para la limpieza del dataset
# - Mediante una análisis EDA (apoyándose en visualizaciones), contestar a las siguientes preguntas:
#
# **1.**¿Cómo ha evolucionado la valoración de los clientes a lo largo de los años?
#
# **2.**¿Cuál es la calificación promedio por Reviewer_Location?
#
# **3.**Calificación promedio por sucursal
#
# **4.**Calificaciones de Grupo por sucursal y año
#
# **Paso #3: Normalización del texto**
#
# - Ejecute la normalizacion de la columna **Review_Text**, creando una nueva columna **Review_Text_Clean**.
#
# - La normalización del texto implica tareas de segmentación, tokenización, eliminación de palabras vacías (stopwords) y lematización de los comentarios (Review_Text) como los principales pasos a ejecutar para el procesamiento del lenguaje natural (NLP).  Puede considerar también solo tokens con una longitud mayor a 5 dígitos en minúsculas.
#
# - Creación de bolsa de palabras (BOW)
# Para los datos de texto normalizados,  ​​utilizando el enfoque de vectorización de conteo o vectorización TF-IDF.
#
# **Paso #4. Análisis de Sentimiento**
#
# El **Análisis de Sentimiento** es uno de los casos de uso más populares del procesamiento de lenguaje natural (NLP).
#
# - Cree dos nuevas columnas en el dataset para contemplar la polarización de cada uno de los comentarios (positivo, neutral y negativo) a nivel:
#
# >1. Análisis del texto.
# >2. Análisis de los ratings asociados al texto.
#
# - Considere alguna la técnica o proceso utilizado para tal fin.  Explique.
#
# - ¿Existe mucha o poca diferencia entre la polarización obtenida a partir del análisis del texto vs. el obtenido a partir de los ratings asociados?.  Explique.
#
# **Paso #5. Modelización, Predicción y Evaluación de los resultados**
#
# Entrenar un algoritmo de ML para generar un modelo de clasificación adecuado sobre los datos procesados ​​para la clasificación de sentimientos (elija una de las dos columnas creadas en el paso 4 que contemplan la polarización).
#
# Si entrena más de un algoritmo, elija aquel que produjo el mejor modelo de clasificación.
#
# ## **Sus conclusiones**
#
# Finalmente, producto del análisis y la evaluación de los resultados de la modelización, responder a las siguientes preguntas:
#
# **1.** ¿Cuál de los tres parques debe ser considerarlo como el más feliz (positivo)? ¿Son los ratings o los comentarios los que inciden más en dicha polarización? ¿Por qué?
#
# **2.** ¿Cree usted que es suficiente considerar al parque (sucursal) menos feliz a aquel que recibió más comentarios negativos? ¿Cuáles fueron las palabras más negativas? Justifique su respuesta.
#
# **CONSIDERACIONES:**
#
# *  Se evaluará la organización/orden para el desarrollo.
# *  Se valorará la ayuda de visualizaciones que respalden sus respuestas.

# %% [markdown]
# ---
#
# ## **SOLUCION:**

# %% [markdown]
# ### **Paso #1:  Carga del Dataset**

# %%
#TO DO

# %% [markdown]
# ### **Paso #2: Preprocesamiento de los datos**
#
# El preprocesamiento de texto implica normalización, tokenización, eliminación de palabras vacías (stopwords) y derivación/lematización

# %% [markdown]
# **1.¿Cómo ha evolucionado el rating de los clientes a lo largo de los años?**

# %%
#TO DO

# %% [markdown]
# **2.¿Cuál es el rating promedio por Reviewer_Location?**

# %%
#TO DO

# %% [markdown]
# **3.Rating promedio por Parque (sucursal)**

# %%
#TO DO

# %% [markdown]
# **4.Ratings por Parque (sucursal) y año**

# %%
#TO DO

# %% [markdown]
# ### **Paso #3: Normalización del texto**
#
# Ejecute la normalizacion de la columna **Review_Text**, creando una nueva columna **Review_Text_Clean**.
#
# La normalización del texto implica segmentación, tokenización, eliminación de palabras vacías (stopwords) y lematización de los comentarios (Review_Text) como los principales pasos a ejecutar para el procesamiento del lenguaje natural (NLP).   Puede considerar también solo tokens con una longitud mayor a 5 dígitos en minúsculas.

# %%
#TO DO

# %% [markdown]
# Creación de bolsa de palabras (BOW) para los datos de texto normalizados, ​​utilizando el enfoque de vectorización de conteo o vectorización TF-IDF.

# %%
#TO DO

# %% [markdown]
# ### **Paso #4. Análisis de Sentimiento**

# %% [markdown]
# Cree dos nuevas columnas en el dataset para contemplar la polarización de cada uno de los comentarios (positivo, neutral y negativo) a nivel:
#
# - Análisis del texto.
# - Análisis de los ratings asociados al texto.

# %% [markdown]
# Considere alguna la técnica o proceso utilizado para obtener la polarización en cada caso. Explique.

# %%
#TO DO

# %% [markdown]
# ¿Existe mucha o poca diferencia entre la polarización obtenida a partir del análisis del texto vs. el obtenido a partir de los ratings asociados?.  Explique.

# %% [markdown]
# ### **Paso #5. Modelización, Predicción y Evaluación de los resultados**
#
# Entrenar un algoritmo de ML para generar un modelo de clasificación adecuado sobre los datos procesados ​​para la clasificación de sentimientos (elija una de las dos columnas creadas en el paso 4 que contemplan la polarización).
#
# Si entrena más de un algoritmo, elija aquel que produjo el mejor modelo de clasificación.

# %%
#TO DO
# Modelizacion

# %%
#TO DO
# Prediccion

# %%
#TO DO
# Evaluacion de los resultados

# %% [markdown]
# ## **Mis conclusiones**

# %% [markdown]
# **1. ¿Cuál de los tres parques debe ser considerarlo como el más feliz (positivo)? ¿Son los ratings o los comentarios los que inciden más en dicha polarización? ¿Por qué?**

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# **2. ¿Cree usted que es suficiente considerar al parque (sucursal) menos feliz a aquel que recibió más comentarios negativos? ¿Cuáles fueron las palabras más negativas? Justifique su respuesta.**

# %% [markdown]
# **Respuesta:**
