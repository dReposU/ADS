# %% [markdown]
# ---
# **Parcial Aplicaciones de Data-Science**
#
# **Semestre 2026-01**
#
# **Nombre del Alumno:**
# **Código:**
#
#
# ---

# %% [markdown]
# ## **CASO DE ANALISIS:** SISTEMA HÍBRIDO DE CLASIFICACIÓN Y RECOMENDACIÓN DE PRODUCTOS
#
# Usted ha sido contratado por una plataforma de e-commerce que desea mejorar la experiencia del usuario. El dataset proporcionado contiene reseñas de productos, calificaciones y metadatos.
# El objetivo es construir un flujo que limpie el texto, clasifique el sentimiento de las reseñas y utilice esa información para recomendar productos similares que tengan una percepción positiva.
#
#
# El Dataset es de Amazon Fine Food Reviews.
# Aqui enlace https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews$0
#
# ## **NORMALIZACION DE TEXTO (3 pts)**
#
# **1) Creacion de Corpus**
#
# Importa el dataset
#
# **2) Normalizar corpus**
#
#
# A partir de la columna de texto (ReviewText), realice el preprocesamiento necesario para limpiar el corpus.
#
# * Convertir a minusculas
# * Eliminar signos de puntuación, números y caracteres especiales, stopwords
# * Realice tokenización y transformar cada token a su lema
# * Elimine los tokens menores a tres (3) dígitos
#
# ## **CLASIFICACION DE SENTIMIENTO (4 pts)**
#
# Utilice el texto procesado para entrenar un modelo que prediga si una reseña es de un cliente satisfecho (Score > 3).
#
# **3)Clasificacion**
#
# 3.1 Vectorización TF-IDF: Transforme el corpus en una matriz de términos utilizando la técnica de Frecuencia de Documento Inversa (TF-IDF).
#
# 3.2. Entrenamiento del Modelo: Divida los datos en entrenamiento y test. Implemente el clasificador Multinomial Naive Bayes, SVC y logistic regresion.
#
# 3.3. Evaluación: Muestre la Matriz de Confusión de cada resultado graficamente y reporte las métricas de Accuracy,Precisión, Recall y F1-Score de cada modelo. Y comente los resultados en sus propias palabras cual es el mejor modelo y porque
#
#
# ## **SISTEMA DE RECOMENDACION (4 pts)**
#
# **4) Sistema de recomendación**
#
# 4.1. Similitud de Coseno: Calcule la matriz de similitud de coseno entre los vectores de los productos.
#
# 4.2. Función de Recomendación: Cree una función recomendar_productos(product_id, top_n=5) que devuelva los nombres de los productos más parecidos al ID ingresado.
#
# 4.3. Integración: Modifique la función para que el sistema solo recomiende productos que el modelo de Naive Bayes (del Bloque 2) clasifique con sentimiento positivo.
#
#
# ## **INTERPRETACIÓN (3 pts)**
#
# Evalúe la calidad de las recomendaciones y analice el impacto del modelo en el negocio.
#
# **5) Interpretación de resultados**
#
# 5.1. Métrica nDCG: Si quisiera calcular nDCG como lo haría usando lo aprendido en clase aplicado para el caso anterior
#
# 5.2. Análisis de Serendipia: Explique bajo qué escenario su sistema podría recomendar un producto "sorprendente" (Serendipia) y por qué es importante para evitar el aburrimiento del usuario.
#
# 5.3. Interpretación Técnica: Responda: ¿Cómo afecta una mala tokenización inicial (Bloque 1) al cálculo de la Similitud de Coseno en el Bloque 3? Sustente su respuesta basándose en el concepto de Espacio Vectorial.

# %% [markdown]
# ## **SOLUCIÓN**

# %% [markdown]
# ## **NORMALIZACION DE TEXTO**

# %%
'''
1) Creacion de Corpus

Importa el dataset

2) Normalizar corpus

A partir de la columna de texto (ReviewText), realice el preprocesamiento necesario para limpiar el corpus.

Convertir a minusculas
Eliminar signos de puntuación, números y caracteres especiales, stopwords
Realice tokenización y transformar cada token a su lema
Elimine los tokens menores a tres (3) dígitos
'''

# %% [markdown]
# ## **CLASIFICACION DE SENTIMIENTO**

# %%
'''
3.1 Vectorización TF-IDF: Transforme el corpus en una matriz de términos utilizando la técnica de Frecuencia de Documento Inversa (TF-IDF).
3.2. Entrenamiento del Modelo: Divida los datos en entrenamiento y test. Implemente el clasificador Multinomial Naive Bayes, SVC y logistic regresion.
3.3. Evaluación: Muestre la Matriz de Confusión de cada resultado graficamente y reporte las métricas de Accuracy,Precisión, Recall y F1-Score de cada modelo.
Y comente los resultados en sus propias palabras cual es el mejor modelo y porque
'''

# %% [markdown]
# ## **SISTEMA DE RECOMENDACION**

# %%
'''
4.1. Similitud de Coseno: Calcule la matriz de similitud de coseno entre los vectores de los productos.
4.2. Función de Recomendación: Cree una función recomendar_productos(product_id, top_n=5) que devuelva los nombres de los productos más parecidos al ID ingresado.
4.3. Integración: Modifique la función para que el sistema solo recomiende productos que el modelo de Naive Bayes (del Bloque 2) clasifique con sentimiento positivo.

'''

# %% [markdown]
# ## **INTERPRETACIÓN**

# %%
'''
5.1. Métrica nDCG: Si quisiera calcular nDCG como lo haría usando lo aprendido en clase aplicado para el caso anterior
5.2. Análisis de Serendipia: Explique bajo qué escenario su sistema podría recomendar un producto "sorprendente" (Serendipia) y por qué es importante para evitar el aburrimiento del usuario.
5.3. Interpretación Técnica: Responda: ¿Cómo afecta una mala tokenización inicial (Bloque 1) al cálculo de la Similitud de Coseno en el Bloque 3? Sustente su respuesta basándose en el concepto de Espacio Vectorial.

'''

# %% [markdown]
# Una vez desarrolladas todas las operaciones solicitadas, no olvide adjuntar como respuesta a esta evaluación:
#
# * **Este Notebook** con sus datos personales conteniendo su solución
