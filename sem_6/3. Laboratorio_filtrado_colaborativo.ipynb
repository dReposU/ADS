# %% [markdown]
# "El Recomendador de Cine de Culto":
#
# ¡Felicidades! Has sido contratado por una nueva plataforma de streaming que quiere competir con Netflix. Tu primera tarea es construir un Sistema de Recomendación Colaborativo utilizando el dataset de MovieLens que ya tenemos cargado.
#
# En este ejercicio, no usaremos el modelo KNNWithMeans. En su lugar, utilizaremos el algoritmo SVD (Singular Value Decomposition) para predecir qué calificación le daría un usuario específico a una película que aún no ha visto.

# %% [markdown]
# Objetivos del ejercicio:
#
# 1- Carga y Filtrado: Carga el archivo ratings.csv y filtra los datos para quedarte solo con los usuarios que hayan calificado más de 50 películas (esto ayuda a que el modelo sea más preciso).

# %% [markdown]
# 2- Preparación de Surprise: Configura el objeto Reader y carga los datos en el formato que requiere la librería surprise.

# %% [markdown]
# 3- Entrenamiento: Divide el dataset en 75% para entrenamiento y 25% para prueba. Entrena un modelo SVD con 50 factores latentes (n_factors=50).
# +1

# %% [markdown]
# 4- Predicción Individual: Elige al Usuario ID: 15 y la Película ID: 2571 (The Matrix). Utiliza el método model.predict(uid, iid) para ver qué calificación le asignaría el sistema.

# %% [markdown]
# 5- Evaluación: Calcula el error RMSE del modelo sobre el conjunto de prueba y explica brevemente qué significa ese número.
